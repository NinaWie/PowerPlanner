# %%
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
g = nx.Graph()
g.add_node(1)
g.add_node(2)
g.add_edge(1,2)
g.add_node(3)
g.add_edges_from([(1,2), (1,3)])
# g.add_weighted_edges_from([(1, 2, 0.125), (1, 3, 0.75), (2, 4, 1.2), (3, 4, 0.375)])
# labels = nx.get_edge_attributes(g,'weight') # returns dictionary
print(g.number_of_nodes(), g.number_of_edges())
g.remove_node(2)
# Out:
# 3 2

# %%
edge_list = [(0, 1), (1, 2), (2, 3)]
g = nx.Graph(edge_list)
print(list(g.edges()))
g.add_node((1,2))
# Out:
# [(0, 1), (1, 2), (2, 3)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-2855b3e3a1f9> in <module>
#       2 g = nx.Graph(edge_list)
#       3 print(list(g.edges()))
# ----> 4 g.add_node([1,2])
#
# ~/Desktop/thesis.nosync/power_planner/powerenv/lib/python3.7/site-packages/networkx/classes/graph.py in add_node(self, node_for_adding, **attr)
#     514         doesn't change on mutables.
#     515         """
# --> 516         if node_for_adding not in self._node:
#     517             self._adj[node_for_adding] = self.adjlist_inner_dict_factory()
#     518             attr_dict = self._node[node_for_adding] = self.node_attr_dict_factory()
#
# TypeError: unhashable type: 'list'

# %%
g = nx.Graph()
for i in range(5):
    x = np.random.randint(1,5)
    y = np.random.randint(1,5)
    g.add_node(i, pos=(x,y)) # must specify positions for drawing
    
for i in range(5):
    r = np.random.randint(1,5)
    g.add_edge(i,r)
    
g.add_weighted_edges_from([(1, 2, 0.125), (1, 3, 0.75), (2, 4, 1.2), (3, 4, 0.375)])

# %%
labels = nx.get_edge_attributes(g,'weight') # returns dictionary
pos = nx.get_node_attributes(g,'pos')
print(pos)
plt.figure(figsize=(20,10))
nx.draw(g,pos)
nx.draw_networkx_edge_labels(g, pos, edge_labels=labels)
plt.show()
# Out:
# {0: (4, 4), 1: (3, 4), 2: (2, 3), 3: (1, 2), 4: (2, 4)}

# %%
nx.draw(g, with_labels=True, font_weight='bold')
plt.show()
